# %%
#Pytorch
import torch
import torch.nn as nn
import torch.autograd as autograd
import torch.optim as optim
import torch.nn.functional as F
from torch.distributions import multivariate_normal, normal
#Python Libs
import numpy as np
from time import time
import datetime
import gc
import math
#Implementations
from model.models import INDIG
from dataset import GDataset
from batch_test import *

# %%
class Config(object):
    def __init__(self, dataset, estimator):
        self.dataset = dataset 
        self.path = 'data/' + self.dataset + '/'
        self.estimator = estimator
        self.user_dataset = self.path + self.dataset + '.train.ui'
        self.group_dataset = self.path + self.dataset
        self.user_in_group_path = self.path+ self.dataset + ".train.gu"
        self.embedding_size = 32
        self.epoch = 256
        self.num_negatives = 4
        self.batch_size = 256
        self.lr = 0.001
        self.drop_ratio = 0.6
        self.selfsuplamb = 0.0001
        self.topK = [10,]
        self.seed = 2022
        self.eval_freq = 5
        self.cuda = True
        self.WU_point = -1 #warm_up point
        self.ui_available = False #num of pretrains
    
    def __str__(self):
        print('{:<25}: {:}'.format('Data', config.dataset))
        print('{:<25}: {:}'.format('Estimator', config.estimator))
        print('{:<25}: {:}'.format('#neg', config.num_negatives))
        print('{:<25}: {:}'.format('lr', config.lr))
        print('{:<25}: {:}'.format('drop-rate', config.drop_ratio))
        print('{:<25}: {:}'.format('self-sup', config.selfsuplamb))     
        return ''

# %%
config = Config('douban', 'mf3') #meetupCA, gwl
print(vars(config))
torch.manual_seed(config.seed)  # Set the random seed manually for reproducibility.
# Out:
# {'dataset': 'douban', 'path': 'data/douban/', 'estimator': 'mf3', 'user_dataset': 'data/douban/douban.train.ui', 'group_dataset': 'data/douban/douban', 'user_in_group_path': 'data/douban/douban.train.gu', 'embedding_size': 32, 'epoch': 256, 'num_negatives': 4, 'batch_size': 256, 'lr': 0.001, 'drop_ratio': 0.6, 'selfsuplamb': 0.0001, 'topK': [10], 'seed': 2022, 'eval_freq': 5, 'cuda': True, 'WU_point': -1, 'ui_available': False}

# %%
device = torch.device("cuda" if config.cuda else "cpu")
print(device)
# Out:
# cuda

# %%
dataset = GDataset(config.user_dataset, config.group_dataset, config.user_in_group_path, config.num_negatives)
num_groups, num_users, num_items = dataset.num_groups, dataset.num_users, dataset.num_items
print("num_groups: "+str(num_groups)+" num_users: "+str(num_users)+" num_items: "+str(num_items))

gu_dict = dataset.gu_dict
ui_dict = None
if config.ui_available:
    ui_dict = dataset.ui_dict

test_warm = dataset.load_rating_file_as_dict(config.group_dataset + ".test.rating_warm")
test_cold = dataset.load_rating_file_as_dict(config.group_dataset + ".test.rating_cold")
dataset.num_negatives = config.num_negatives
valid = dataset.load_rating_file_as_dict(config.group_dataset + ".valid.rating")
# Out:
# num_groups: 92489 num_users: 63893 num_items: 15741

# %%
def print_eval(ret, KS=[], data_type = 'warm'):
    for i, k in enumerate(KS):
        print('\t\t @%d: (%s) HR = %.4f, NDCG = %.4f, Rec = %.4f' % (k, data_type, ret['hit_ratio'][i], ret['ndcg'][i], ret['recall'][i]))

# %%
def valid_model(model, test_groups, Ks, group_trainRatings, num_items, device):
    valid_group = []
    valid_item = []
    for g in test_groups:
        for v in test_groups[g]:
            valid_group.append(g)
            valid_item.append(v)

            
    group_var = torch.LongTensor(valid_group).to(device)
    item_var = torch.LongTensor(valid_item).to(device)

    model.eval()
    rating, _ = model(group_var, item_var)
    avg_rating = torch.mean(rating).item()
    return avg_rating

# %%
model = INDIG(num_users, num_items, num_groups, config.embedding_size, gu_dict, dataset.group_trainRatings, ui_dict, config.drop_ratio, device).to(device)

best_checkpoint = -1.0
sub_checkpoint = -1.0
best_weights_path = None

print(config)

optimizer = optim.Adam(model.parameters(), lr=config.lr)
print('====================================')
# train the model
for epoch in range(config.epoch): 
    train_loader = dataset.get_group_dataloader(config.batch_size)
    t1 = time()
    tau = 1.0 - 0.25*(math.cos(math.pi*epoch/config.epoch)+1) #cosine annealing
    losses = []
    model.train()
    for batch_id, (g, pi_ni) in enumerate(train_loader):
        # Data Load
        group_input = g.to(device, non_blocking=True)
        pos_item_input = pi_ni[:, 0].to(device, non_blocking=True)
        neg_item_input = pi_ni[:, 1].to(device, non_blocking=True)

        #zero
        optimizer.zero_grad()

        transduc_loss, dkl, induc_loss, selfsup_loss = model(group_input, pos_item_input, neg_item_input)
        loss = (1-tau)*(transduc_loss + dkl +  config.selfsuplamb*selfsup_loss) + tau*induc_loss

        if not torch.isinf(loss.data) and not torch.isnan(loss.data):
            losses.append(float(loss.item()))
        else:
            print('ERROR!\t', torch.mean(-log_p).item(), torch.mean(-log_p2).item(), torch.mean(dkl).item(), selfsup_loss.item())
        # Backward
        loss.backward()
        optimizer.step()

    print('Iteration %d,\tloss: [%.4f], time: [%.1fs], tau: [%.3f]' % (epoch, np.mean(np.array(losses)), time() - t1, tau))
    gc.collect()

    if epoch > config.WU_point and epoch%config.eval_freq == 0:
        model.eval()
        with torch.no_grad():
            t2 = time()
            ret = test(model, valid, config.topK,  dataset.group_trainRatings, dataset.num_items, device) #See batch_test
            print('\t Evaluation done [%.1f s]' % (time() - t2))
            print_eval(ret, config.topK)
            cur_sub_checkpoint = ret['hit_ratio'][0]
            current_weights_path = 'weights/INDIG_'+str(config.estimator)+'_'+str(config.dataset)+"_"+str(config.lr)+"_"+str(config.drop_ratio)+"_"+str(config.selfsuplamb)+'_'+str(epoch)
            cur_checkpoint = 0
            '''
            t2 = time()
            ret = test(model, test_cold, config.topK,  dataset.group_trainRatings, dataset.num_items, device) #See batch_test
            print('\t Evaluation done [%.1f s]' % (time() - t2))
            print_eval(ret, config.topK, data_type='cold')
            cur_checkpoint = ret['hit_ratio'][0]
            '''
            if (best_checkpoint < cur_checkpoint and sub_checkpoint == cur_sub_checkpoint) or (sub_checkpoint < cur_sub_checkpoint):
                best_weights_path = current_weights_path
                best_checkpoint = cur_checkpoint
                sub_checkpoint = cur_sub_checkpoint                
                torch.save(model.state_dict(), current_weights_path)
                print('SAVED! at epoch ', epoch)
# Out:
# Data                     : douban
# Estimator                : mf3
# #neg                     : 4
# lr                       : 0.001
# drop-rate                : 0.6
# self-sup                 : 0.0001
#
# ====================================
# Iteration 0,	loss: [0.5822], time: [1020.1s], tau: [0.500]
# 	 Evaluation done [2470.7 s]
# 		 @10: (warm) HR = 0.0042, NDCG = 0.0013, Rec = 0.0042
# SAVED! at epoch  0
# Iteration 1,	loss: [0.4017], time: [1025.0s], tau: [0.500]
# Iteration 2,	loss: [0.2920], time: [1017.9s], tau: [0.500]
# Iteration 3,	loss: [0.2370], time: [1020.6s], tau: [0.500]
# Iteration 4,	loss: [0.2044], time: [1017.1s], tau: [0.500]
# Iteration 5,	loss: [0.1817], time: [1004.1s], tau: [0.500]
# 	 Evaluation done [2336.6 s]
# 		 @10: (warm) HR = 0.0106, NDCG = 0.0057, Rec = 0.0106
# SAVED! at epoch  5
# Iteration 6,	loss: [0.1649], time: [1018.0s], tau: [0.501]
# Iteration 7,	loss: [0.1540], time: [1020.1s], tau: [0.501]
# Iteration 8,	loss: [0.1437], time: [1009.4s], tau: [0.501]
# Iteration 9,	loss: [0.1362], time: [1023.5s], tau: [0.502]
# Iteration 10,	loss: [0.1290], time: [1003.4s], tau: [0.502]
# 	 Evaluation done [2543.0 s]
# 		 @10: (warm) HR = 0.0297, NDCG = 0.0137, Rec = 0.0297
# SAVED! at epoch  10
# Iteration 11,	loss: [0.1237], time: [1024.7s], tau: [0.502]
# Iteration 12,	loss: [0.1178], time: [1011.6s], tau: [0.503]
# Iteration 13,	loss: [0.1145], time: [1013.8s], tau: [0.503]
# Iteration 14,	loss: [0.1098], time: [1031.1s], tau: [0.504]
# Iteration 15,	loss: [0.1066], time: [1027.7s], tau: [0.504]
# 	 Evaluation done [2305.3 s]
# 		 @10: (warm) HR = 0.0381, NDCG = 0.0189, Rec = 0.0381
# SAVED! at epoch  15
# Iteration 16,	loss: [0.1035], time: [1023.8s], tau: [0.505]
# Iteration 17,	loss: [0.1015], time: [1026.3s], tau: [0.505]
# Iteration 18,	loss: [0.0985], time: [1018.3s], tau: [0.506]
# Iteration 19,	loss: [0.0961], time: [1023.3s], tau: [0.507]
# Iteration 20,	loss: [0.0930], time: [1021.0s], tau: [0.507]
# 	 Evaluation done [2506.1 s]
# 		 @10: (warm) HR = 0.0318, NDCG = 0.0157, Rec = 0.0318
# Iteration 21,	loss: [0.0921], time: [1012.1s], tau: [0.508]
# Iteration 22,	loss: [0.0900], time: [1015.4s], tau: [0.509]
# Iteration 23,	loss: [0.0867], time: [1025.3s], tau: [0.510]
# Iteration 24,	loss: [0.0863], time: [1017.3s], tau: [0.511]
# Iteration 25,	loss: [0.0847], time: [1020.9s], tau: [0.512]
# 	 Evaluation done [2364.0 s]
# 		 @10: (warm) HR = 0.0466, NDCG = 0.0242, Rec = 0.0466
# SAVED! at epoch  25
# Iteration 26,	loss: [0.0829], time: [1023.0s], tau: [0.513]
# Iteration 27,	loss: [0.0819], time: [1019.3s], tau: [0.514]
# Iteration 28,	loss: [0.0801], time: [1016.7s], tau: [0.515]
# Iteration 29,	loss: [0.0789], time: [1014.9s], tau: [0.516]
# Iteration 30,	loss: [0.0769], time: [1013.0s], tau: [0.517]
# 	 Evaluation done [2419.5 s]
# 		 @10: (warm) HR = 0.0508, NDCG = 0.0277, Rec = 0.0508
# SAVED! at epoch  30
# Iteration 31,	loss: [0.0764], time: [1016.4s], tau: [0.518]
# Iteration 32,	loss: [0.0762], time: [1015.8s], tau: [0.519]
# Iteration 33,	loss: [0.0747], time: [1019.9s], tau: [0.520]
# Iteration 34,	loss: [0.0739], time: [1017.8s], tau: [0.521]
# Iteration 35,	loss: [0.0730], time: [1025.6s], tau: [0.523]
# 	 Evaluation done [2425.4 s]
# 		 @10: (warm) HR = 0.0572, NDCG = 0.0277, Rec = 0.0572
# SAVED! at epoch  35
# Iteration 36,	loss: [0.0719], time: [1015.9s], tau: [0.524]
# Iteration 37,	loss: [0.0716], time: [1020.5s], tau: [0.525]
# Iteration 38,	loss: [0.0710], time: [1028.9s], tau: [0.527]
# Iteration 39,	loss: [0.0698], time: [1028.1s], tau: [0.528]
# Iteration 40,	loss: [0.0684], time: [1021.3s], tau: [0.530]
# 	 Evaluation done [2337.8 s]
# 		 @10: (warm) HR = 0.0551, NDCG = 0.0339, Rec = 0.0551
# Iteration 41,	loss: [0.0688], time: [1029.2s], tau: [0.531]
# Iteration 42,	loss: [0.0682], time: [1023.8s], tau: [0.532]
# Iteration 43,	loss: [0.0667], time: [1028.9s], tau: [0.534]
# Iteration 44,	loss: [0.0660], time: [1015.7s], tau: [0.536]
# Iteration 45,	loss: [0.0656], time: [1028.2s], tau: [0.537]
# 	 Evaluation done [2507.3 s]
# 		 @10: (warm) HR = 0.0636, NDCG = 0.0332, Rec = 0.0636
# SAVED! at epoch  45
# Iteration 46,	loss: [0.0651], time: [1011.7s], tau: [0.539]
# Iteration 47,	loss: [0.0646], time: [1021.0s], tau: [0.540]
# Iteration 48,	loss: [0.0642], time: [1019.0s], tau: [0.542]
# Iteration 49,	loss: [0.0637], time: [1025.7s], tau: [0.544]
# Iteration 50,	loss: [0.0633], time: [1025.0s], tau: [0.546]
# 	 Evaluation done [2292.5 s]
# 		 @10: (warm) HR = 0.0593, NDCG = 0.0324, Rec = 0.0593
# Iteration 51,	loss: [0.0629], time: [1013.6s], tau: [0.547]
# Iteration 52,	loss: [0.0626], time: [1026.3s], tau: [0.549]
# Iteration 53,	loss: [0.0624], time: [1013.0s], tau: [0.551]
# Iteration 54,	loss: [0.0623], time: [1016.6s], tau: [0.553]
# Iteration 55,	loss: [0.0617], time: [1022.1s], tau: [0.555]
# 	 Evaluation done [2493.9 s]
# 		 @10: (warm) HR = 0.0551, NDCG = 0.0297, Rec = 0.0551
# Iteration 56,	loss: [0.0614], time: [1026.2s], tau: [0.557]
# Iteration 57,	loss: [0.0600], time: [1016.9s], tau: [0.559]
# Iteration 58,	loss: [0.0599], time: [1034.8s], tau: [0.561]
# Iteration 59,	loss: [0.0602], time: [1024.6s], tau: [0.563]
# Iteration 60,	loss: [0.0587], time: [1023.6s], tau: [0.565]
# 	 Evaluation done [2324.3 s]
# 		 @10: (warm) HR = 0.0572, NDCG = 0.0314, Rec = 0.0572
# Iteration 61,	loss: [0.0588], time: [1015.2s], tau: [0.567]
# Iteration 62,	loss: [0.0586], time: [1020.2s], tau: [0.569]
# Iteration 63,	loss: [0.0588], time: [1021.0s], tau: [0.571]
# Iteration 64,	loss: [0.0584], time: [1024.3s], tau: [0.573]
# Iteration 65,	loss: [0.0576], time: [1031.9s], tau: [0.575]
# 	 Evaluation done [2407.1 s]
# 		 @10: (warm) HR = 0.0572, NDCG = 0.0288, Rec = 0.0572
# Iteration 66,	loss: [0.0579], time: [1018.3s], tau: [0.578]
# Iteration 67,	loss: [0.0573], time: [1026.9s], tau: [0.580]
# Iteration 68,	loss: [0.0567], time: [1023.2s], tau: [0.582]
# Iteration 69,	loss: [0.0565], time: [1025.6s], tau: [0.584]
# Iteration 70,	loss: [0.0566], time: [1020.1s], tau: [0.587]
# 	 Evaluation done [2398.9 s]
# 		 @10: (warm) HR = 0.0699, NDCG = 0.0362, Rec = 0.0699
# SAVED! at epoch  70
# Iteration 71,	loss: [0.0570], time: [1025.3s], tau: [0.589]
# Iteration 72,	loss: [0.0561], time: [1026.5s], tau: [0.591]
# Iteration 73,	loss: [0.0555], time: [1020.7s], tau: [0.594]
# Iteration 74,	loss: [0.0555], time: [1018.5s], tau: [0.596]
# Iteration 75,	loss: [0.0554], time: [1024.9s], tau: [0.599]
# 	 Evaluation done [2319.3 s]
# 		 @10: (warm) HR = 0.0742, NDCG = 0.0362, Rec = 0.0742
# SAVED! at epoch  75
# Iteration 76,	loss: [0.0553], time: [1017.3s], tau: [0.601]
# Iteration 77,	loss: [0.0541], time: [1021.3s], tau: [0.604]
# Iteration 78,	loss: [0.0544], time: [1003.8s], tau: [0.606]
# Iteration 79,	loss: [0.0543], time: [1005.0s], tau: [0.609]
# Iteration 80,	loss: [0.0538], time: [1025.0s], tau: [0.611]
# 	 Evaluation done [2474.6 s]
# 		 @10: (warm) HR = 0.0657, NDCG = 0.0366, Rec = 0.0657
# Iteration 81,	loss: [0.0538], time: [1010.2s], tau: [0.614]
# Iteration 82,	loss: [0.0535], time: [1021.1s], tau: [0.616]
# Iteration 83,	loss: [0.0534], time: [1023.7s], tau: [0.619]
# Iteration 84,	loss: [0.0531], time: [1029.3s], tau: [0.621]
# Iteration 85,	loss: [0.0529], time: [1025.6s], tau: [0.624]
# 	 Evaluation done [2276.1 s]
# 		 @10: (warm) HR = 0.0763, NDCG = 0.0409, Rec = 0.0763
# SAVED! at epoch  85
# Iteration 86,	loss: [0.0526], time: [1024.5s], tau: [0.627]
# Iteration 87,	loss: [0.0528], time: [1029.8s], tau: [0.629]
# Iteration 88,	loss: [0.0523], time: [1034.7s], tau: [0.632]
# Iteration 89,	loss: [0.0522], time: [1030.3s], tau: [0.635]
# Iteration 90,	loss: [0.0520], time: [1028.4s], tau: [0.638]
# 	 Evaluation done [2469.0 s]
# 		 @10: (warm) HR = 0.0847, NDCG = 0.0484, Rec = 0.0847
# SAVED! at epoch  90
# Iteration 91,	loss: [0.0518], time: [1023.6s], tau: [0.640]
# Iteration 92,	loss: [0.0515], time: [1014.4s], tau: [0.643]
# Iteration 93,	loss: [0.0515], time: [1024.4s], tau: [0.646]
# Iteration 94,	loss: [0.0510], time: [1025.3s], tau: [0.649]
# Iteration 95,	loss: [0.0512], time: [1025.3s], tau: [0.652]
# 	 Evaluation done [2317.1 s]
# 		 @10: (warm) HR = 0.0826, NDCG = 0.0438, Rec = 0.0826
# Iteration 96,	loss: [0.0505], time: [1021.3s], tau: [0.654]
# Iteration 97,	loss: [0.0512], time: [1022.8s], tau: [0.657]
# Iteration 98,	loss: [0.0509], time: [1021.3s], tau: [0.660]
# Iteration 99,	loss: [0.0497], time: [1018.8s], tau: [0.663]
# Iteration 100,	loss: [0.0499], time: [1014.8s], tau: [0.666]
# 	 Evaluation done [2376.2 s]
# 		 @10: (warm) HR = 0.0678, NDCG = 0.0364, Rec = 0.0678
# Iteration 101,	loss: [0.0501], time: [1016.9s], tau: [0.669]
# Iteration 102,	loss: [0.0498], time: [1023.2s], tau: [0.672]
# Iteration 103,	loss: [0.0499], time: [1029.1s], tau: [0.674]
# Iteration 104,	loss: [0.0498], time: [1021.4s], tau: [0.677]
# Iteration 105,	loss: [0.0496], time: [1024.2s], tau: [0.680]
# 	 Evaluation done [2361.1 s]
# 		 @10: (warm) HR = 0.0847, NDCG = 0.0448, Rec = 0.0847
# Iteration 106,	loss: [0.0489], time: [1029.1s], tau: [0.683]
# Iteration 107,	loss: [0.0493], time: [1025.9s], tau: [0.686]
# Iteration 108,	loss: [0.0488], time: [1018.4s], tau: [0.689]
# Iteration 109,	loss: [0.0490], time: [1019.5s], tau: [0.692]
# Iteration 110,	loss: [0.0476], time: [1022.2s], tau: [0.695]
# 	 Evaluation done [2275.4 s]
# 		 @10: (warm) HR = 0.0932, NDCG = 0.0503, Rec = 0.0932
# SAVED! at epoch  110
# Iteration 111,	loss: [0.0478], time: [1017.5s], tau: [0.698]
# Iteration 112,	loss: [0.0481], time: [1017.4s], tau: [0.701]
# Iteration 113,	loss: [0.0478], time: [1019.3s], tau: [0.704]
# Iteration 114,	loss: [0.0474], time: [1013.2s], tau: [0.707]
# Iteration 115,	loss: [0.0477], time: [1024.9s], tau: [0.710]
# 	 Evaluation done [2483.9 s]
# 		 @10: (warm) HR = 0.0826, NDCG = 0.0473, Rec = 0.0826
# Iteration 116,	loss: [0.0474], time: [1020.9s], tau: [0.713]
# Iteration 117,	loss: [0.0472], time: [1014.6s], tau: [0.716]
# Iteration 118,	loss: [0.0477], time: [1020.6s], tau: [0.719]
# Iteration 119,	loss: [0.0472], time: [1019.5s], tau: [0.722]
# Iteration 120,	loss: [0.0472], time: [1004.4s], tau: [0.725]
# 	 Evaluation done [2246.3 s]
# 		 @10: (warm) HR = 0.0911, NDCG = 0.0480, Rec = 0.0911
# Iteration 121,	loss: [0.0465], time: [1018.5s], tau: [0.729]
# Iteration 122,	loss: [0.0471], time: [1016.6s], tau: [0.732]
# Iteration 123,	loss: [0.0468], time: [1006.0s], tau: [0.735]
# Iteration 124,	loss: [0.0466], time: [1026.6s], tau: [0.738]
# Iteration 125,	loss: [0.0463], time: [1019.3s], tau: [0.741]
# 	 Evaluation done [2446.1 s]
# 		 @10: (warm) HR = 0.0826, NDCG = 0.0496, Rec = 0.0826
# Iteration 126,	loss: [0.0462], time: [1012.8s], tau: [0.744]
# Iteration 127,	loss: [0.0454], time: [1024.5s], tau: [0.747]
# Iteration 128,	loss: [0.0468], time: [1024.3s], tau: [0.750]
# Iteration 129,	loss: [0.0457], time: [1018.3s], tau: [0.753]
# Iteration 130,	loss: [0.0454], time: [1024.8s], tau: [0.756]
# 	 Evaluation done [2297.1 s]
# 		 @10: (warm) HR = 0.0826, NDCG = 0.0471, Rec = 0.0826
# Iteration 131,	loss: [0.0450], time: [1029.0s], tau: [0.759]
# Iteration 132,	loss: [0.0452], time: [1020.6s], tau: [0.762]
# Iteration 133,	loss: [0.0456], time: [1019.0s], tau: [0.765]
# Iteration 134,	loss: [0.0446], time: [1018.1s], tau: [0.768]
# Iteration 135,	loss: [0.0445], time: [1017.5s], tau: [0.771]
# 	 Evaluation done [2347.7 s]
# 		 @10: (warm) HR = 0.0953, NDCG = 0.0478, Rec = 0.0953
# SAVED! at epoch  135
# Iteration 136,	loss: [0.0451], time: [1016.9s], tau: [0.775]
# Iteration 137,	loss: [0.0447], time: [1020.9s], tau: [0.778]
# Iteration 138,	loss: [0.0446], time: [1015.0s], tau: [0.781]
# Iteration 139,	loss: [0.0448], time: [1011.0s], tau: [0.784]
# Iteration 140,	loss: [0.0439], time: [1025.7s], tau: [0.787]
# 	 Evaluation done [2392.3 s]
# 		 @10: (warm) HR = 0.0953, NDCG = 0.0551, Rec = 0.0953
# Iteration 141,	loss: [0.0441], time: [1023.3s], tau: [0.790]
# Iteration 142,	loss: [0.0449], time: [1026.3s], tau: [0.793]
# Iteration 143,	loss: [0.0433], time: [1021.3s], tau: [0.796]
# Iteration 144,	loss: [0.0436], time: [1026.7s], tau: [0.799]
# Iteration 145,	loss: [0.0436], time: [1022.4s], tau: [0.802]
# 	 Evaluation done [2237.6 s]
# 		 @10: (warm) HR = 0.0784, NDCG = 0.0430, Rec = 0.0784
# Iteration 146,	loss: [0.0437], time: [1028.9s], tau: [0.805]
# Iteration 147,	loss: [0.0433], time: [1028.3s], tau: [0.808]
# Iteration 148,	loss: [0.0432], time: [1022.0s], tau: [0.811]
# Iteration 149,	loss: [0.0432], time: [1018.6s], tau: [0.814]
# Iteration 150,	loss: [0.0430], time: [1024.1s], tau: [0.817]
# 	 Evaluation done [2473.2 s]
# 		 @10: (warm) HR = 0.0826, NDCG = 0.0516, Rec = 0.0826
# Iteration 151,	loss: [0.0429], time: [1013.0s], tau: [0.820]
# Iteration 152,	loss: [0.0433], time: [1013.4s], tau: [0.823]
# Iteration 153,	loss: [0.0428], time: [1008.6s], tau: [0.826]
# Iteration 154,	loss: [0.0423], time: [1025.1s], tau: [0.828]
# Iteration 155,	loss: [0.0427], time: [1025.5s], tau: [0.831]
# 	 Evaluation done [2239.6 s]
# 		 @10: (warm) HR = 0.0869, NDCG = 0.0429, Rec = 0.0869
# Iteration 156,	loss: [0.0427], time: [1023.3s], tau: [0.834]
# Iteration 157,	loss: [0.0425], time: [1032.1s], tau: [0.837]
# Iteration 158,	loss: [0.0418], time: [1025.3s], tau: [0.840]
# Iteration 159,	loss: [0.0421], time: [1016.0s], tau: [0.843]
# Iteration 160,	loss: [0.0411], time: [1022.5s], tau: [0.846]
# 	 Evaluation done [2374.1 s]
# 		 @10: (warm) HR = 0.0805, NDCG = 0.0405, Rec = 0.0805
# Iteration 161,	loss: [0.0413], time: [1025.2s], tau: [0.848]
# Iteration 162,	loss: [0.0419], time: [1010.9s], tau: [0.851]
# Iteration 163,	loss: [0.0418], time: [1025.5s], tau: [0.854]
# Iteration 164,	loss: [0.0416], time: [1027.1s], tau: [0.857]
# Iteration 165,	loss: [0.0413], time: [1028.6s], tau: [0.860]
# 	 Evaluation done [2325.8 s]
# 		 @10: (warm) HR = 0.0932, NDCG = 0.0442, Rec = 0.0932
# Iteration 166,	loss: [0.0412], time: [1018.2s], tau: [0.862]
# Iteration 167,	loss: [0.0413], time: [1023.1s], tau: [0.865]
# Iteration 168,	loss: [0.0412], time: [1023.3s], tau: [0.868]
# Iteration 169,	loss: [0.0404], time: [1021.2s], tau: [0.871]
# Iteration 170,	loss: [0.0407], time: [1026.1s], tau: [0.873]
# 	 Evaluation done [2262.7 s]
# 		 @10: (warm) HR = 0.0805, NDCG = 0.0383, Rec = 0.0805
# Iteration 171,	loss: [0.0401], time: [1021.7s], tau: [0.876]
# Iteration 172,	loss: [0.0408], time: [1016.1s], tau: [0.879]
# Iteration 173,	loss: [0.0412], time: [1025.3s], tau: [0.881]
# Iteration 174,	loss: [0.0404], time: [1017.9s], tau: [0.884]
# Iteration 175,	loss: [0.0399], time: [1017.5s], tau: [0.886]
# 	 Evaluation done [2427.7 s]
# 		 @10: (warm) HR = 0.0847, NDCG = 0.0430, Rec = 0.0847
# Iteration 176,	loss: [0.0402], time: [1015.9s], tau: [0.889]
# Iteration 177,	loss: [0.0396], time: [1010.8s], tau: [0.891]
# Iteration 178,	loss: [0.0402], time: [1022.8s], tau: [0.894]
# Iteration 179,	loss: [0.0390], time: [1017.4s], tau: [0.896]
# Iteration 180,	loss: [0.0393], time: [1021.9s], tau: [0.899]
# 	 Evaluation done [2193.2 s]
# 		 @10: (warm) HR = 0.0826, NDCG = 0.0399, Rec = 0.0826
# Iteration 181,	loss: [0.0399], time: [1012.4s], tau: [0.901]
# Iteration 182,	loss: [0.0399], time: [1018.2s], tau: [0.904]
# Iteration 183,	loss: [0.0394], time: [1012.7s], tau: [0.906]
# Iteration 184,	loss: [0.0396], time: [1016.4s], tau: [0.909]
# Iteration 185,	loss: [0.0391], time: [1018.0s], tau: [0.911]
# 	 Evaluation done [2407.2 s]
# 		 @10: (warm) HR = 0.0890, NDCG = 0.0474, Rec = 0.0890
# Iteration 186,	loss: [0.0385], time: [1020.7s], tau: [0.913]
# Iteration 187,	loss: [0.0389], time: [1021.6s], tau: [0.916]
# Iteration 188,	loss: [0.0394], time: [1014.4s], tau: [0.918]
# Iteration 189,	loss: [0.0386], time: [1020.7s], tau: [0.920]
# Iteration 190,	loss: [0.0393], time: [1027.8s], tau: [0.922]
# 	 Evaluation done [2257.4 s]
# 		 @10: (warm) HR = 0.0826, NDCG = 0.0418, Rec = 0.0826
# Iteration 191,	loss: [0.0387], time: [1016.2s], tau: [0.925]
# Iteration 192,	loss: [0.0391], time: [1023.7s], tau: [0.927]
# Iteration 193,	loss: [0.0384], time: [1019.7s], tau: [0.929]
# Iteration 194,	loss: [0.0379], time: [1018.0s], tau: [0.931]
# Iteration 195,	loss: [0.0384], time: [1012.6s], tau: [0.933]
# 	 Evaluation done [2299.4 s]
# 		 @10: (warm) HR = 0.0869, NDCG = 0.0438, Rec = 0.0869
# Iteration 196,	loss: [0.0377], time: [1018.2s], tau: [0.935]
# Iteration 197,	loss: [0.0377], time: [1018.3s], tau: [0.937]
# Iteration 198,	loss: [0.0385], time: [1025.2s], tau: [0.939]
# Iteration 199,	loss: [0.0380], time: [1032.0s], tau: [0.941]
# Iteration 200,	loss: [0.0378], time: [1028.3s], tau: [0.943]
# 	 Evaluation done [2345.9 s]
# 		 @10: (warm) HR = 0.0869, NDCG = 0.0435, Rec = 0.0869
# Iteration 201,	loss: [0.0376], time: [1021.7s], tau: [0.945]
# Iteration 202,	loss: [0.0381], time: [1008.1s], tau: [0.947]
# Iteration 203,	loss: [0.0372], time: [1019.2s], tau: [0.949]
# Iteration 204,	loss: [0.0377], time: [1023.8s], tau: [0.951]
# Iteration 205,	loss: [0.0374], time: [1023.1s], tau: [0.953]
# 	 Evaluation done [2186.8 s]
# 		 @10: (warm) HR = 0.0742, NDCG = 0.0423, Rec = 0.0742
# Iteration 206,	loss: [0.0375], time: [1025.4s], tau: [0.954]
# Iteration 207,	loss: [0.0371], time: [1027.7s], tau: [0.956]
# Iteration 208,	loss: [0.0373], time: [1024.7s], tau: [0.958]
# Iteration 209,	loss: [0.0366], time: [1014.9s], tau: [0.960]
# Iteration 210,	loss: [0.0367], time: [1028.9s], tau: [0.961]
# 	 Evaluation done [2434.8 s]
# 		 @10: (warm) HR = 0.0826, NDCG = 0.0420, Rec = 0.0826
# Iteration 211,	loss: [0.0368], time: [1011.1s], tau: [0.963]
# Iteration 212,	loss: [0.0368], time: [1014.7s], tau: [0.964]
# Iteration 213,	loss: [0.0364], time: [1021.1s], tau: [0.966]
# Iteration 214,	loss: [0.0362], time: [1025.7s], tau: [0.968]
# Iteration 215,	loss: [0.0368], time: [1030.1s], tau: [0.969]
# 	 Evaluation done [2218.6 s]
# 		 @10: (warm) HR = 0.0784, NDCG = 0.0430, Rec = 0.0784
# Iteration 216,	loss: [0.0362], time: [1022.9s], tau: [0.970]
# Iteration 217,	loss: [0.0358], time: [1028.8s], tau: [0.972]
# Iteration 218,	loss: [0.0360], time: [1025.5s], tau: [0.973]
# Iteration 219,	loss: [0.0363], time: [1013.4s], tau: [0.975]
# Iteration 220,	loss: [0.0363], time: [1028.9s], tau: [0.976]
# 	 Evaluation done [2309.3 s]
# 		 @10: (warm) HR = 0.0890, NDCG = 0.0431, Rec = 0.0890
# Iteration 221,	loss: [0.0361], time: [1025.2s], tau: [0.977]
# Iteration 222,	loss: [0.0358], time: [1016.0s], tau: [0.979]
# Iteration 223,	loss: [0.0358], time: [1021.0s], tau: [0.980]
# Iteration 224,	loss: [0.0358], time: [1019.9s], tau: [0.981]
# Iteration 225,	loss: [0.0356], time: [1029.1s], tau: [0.982]
# 	 Evaluation done [2324.0 s]
# 		 @10: (warm) HR = 0.0869, NDCG = 0.0474, Rec = 0.0869
# Iteration 226,	loss: [0.0354], time: [1018.4s], tau: [0.983]
# Iteration 227,	loss: [0.0350], time: [1023.8s], tau: [0.984]
# Iteration 228,	loss: [0.0350], time: [1017.1s], tau: [0.985]
# Iteration 229,	loss: [0.0346], time: [1016.9s], tau: [0.986]
# Iteration 230,	loss: [0.0353], time: [1017.7s], tau: [0.987]
# 	 Evaluation done [2140.8 s]
# 		 @10: (warm) HR = 0.0763, NDCG = 0.0425, Rec = 0.0763
# Iteration 231,	loss: [0.0354], time: [1015.1s], tau: [0.988]
# Iteration 232,	loss: [0.0347], time: [1015.2s], tau: [0.989]
# Iteration 233,	loss: [0.0352], time: [1008.9s], tau: [0.990]
# Iteration 234,	loss: [0.0347], time: [1028.1s], tau: [0.991]
# Iteration 235,	loss: [0.0344], time: [1016.7s], tau: [0.992]
# 	 Evaluation done [2398.3 s]
# 		 @10: (warm) HR = 0.0763, NDCG = 0.0451, Rec = 0.0763
# Iteration 236,	loss: [0.0349], time: [1022.5s], tau: [0.993]
# Iteration 237,	loss: [0.0347], time: [1022.9s], tau: [0.993]
# Iteration 238,	loss: [0.0344], time: [1020.8s], tau: [0.994]
# Iteration 239,	loss: [0.0340], time: [1027.4s], tau: [0.995]
# Iteration 240,	loss: [0.0342], time: [1028.8s], tau: [0.995]
# 	 Evaluation done [2175.6 s]
# 		 @10: (warm) HR = 0.0784, NDCG = 0.0469, Rec = 0.0784
# Iteration 241,	loss: [0.0334], time: [1016.3s], tau: [0.996]
# Iteration 242,	loss: [0.0343], time: [1028.1s], tau: [0.996]
# Iteration 243,	loss: [0.0338], time: [1028.6s], tau: [0.997]
# Iteration 244,	loss: [0.0340], time: [1010.2s], tau: [0.997]
# Iteration 245,	loss: [0.0337], time: [1026.1s], tau: [0.998]
# 	 Evaluation done [2314.3 s]
# 		 @10: (warm) HR = 0.0720, NDCG = 0.0356, Rec = 0.0720
# Iteration 246,	loss: [0.0338], time: [1027.9s], tau: [0.998]
# Iteration 247,	loss: [0.0333], time: [1029.7s], tau: [0.998]
# Iteration 248,	loss: [0.0331], time: [1028.0s], tau: [0.999]
# Iteration 249,	loss: [0.0336], time: [1027.7s], tau: [0.999]
# Iteration 250,	loss: [0.0332], time: [1026.3s], tau: [0.999]
# 	 Evaluation done [2426.5 s]
# 		 @10: (warm) HR = 0.0657, NDCG = 0.0372, Rec = 0.0657
# Iteration 251,	loss: [0.0333], time: [1031.5s], tau: [1.000]
# Iteration 252,	loss: [0.0326], time: [1026.3s], tau: [1.000]
# Iteration 253,	loss: [0.0327], time: [1027.5s], tau: [1.000]
# Iteration 254,	loss: [0.0338], time: [1026.6s], tau: [1.000]
# Iteration 255,	loss: [0.0329], time: [1027.0s], tau: [1.000]
# 	 Evaluation done [2586.9 s]
# 		 @10: (warm) HR = 0.0890, NDCG = 0.0489, Rec = 0.0890

# %%
model = INDIG(num_users, num_items, num_groups, config.embedding_size, gu_dict, dataset.group_trainRatings, ui_dict, config.drop_ratio, device).to(device)
gc.collect()
state = torch.load(best_weights_path)
model.load_state_dict(state)

print('====================================')
print(best_weights_path)
print(config)


model.eval()
with torch.no_grad():
    ret = test(model, test_cold, config.topK,  dataset.group_trainRatings, dataset.num_items, device) #See batch_test
    print_eval(ret, config.topK[:2], 'cold')
    ret = test(model, test_warm, config.topK,  dataset.group_trainRatings, dataset.num_items, device) #See batch_test
    print_eval(ret, config.topK[:2])

print('====================================')
# Out:
# ====================================
# weights/INDIG_mf3_douban_0.001_0.6_0.0001_135
# Data                     : douban
# Estimator                : mf3
# #neg                     : 4
# lr                       : 0.001
# drop-rate                : 0.6
# self-sup                 : 0.0001
#
# 		 @10: (cold) HR = 0.0266, NDCG = 0.0130, Rec = 0.0266
# 		 @10: (warm) HR = 0.0721, NDCG = 0.0360, Rec = 0.0721
# ====================================
